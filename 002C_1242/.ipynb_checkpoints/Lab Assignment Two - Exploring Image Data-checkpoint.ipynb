# %% [markdown]
# ### Lab Assignment Two: Exploring Image Data

# %% [markdown]
# You are to perform preprocessing and exploratory analysis of a data set: exploring the statistical summaries of the features, visualizing the attributes, and addressing data quality. This report is worth 10% of the final grade. Please upload a report (one per team) with all code used, visualizations, and text in a rendered Jupyter notebook. Any visualizations that cannot be embedded in the notebook, please provide screenshots of the output.

# %% [markdown]
# **Dataset requirements**: Choose a dataset that is comprised of image data. The data should be directories of images. That is, the dataset should not yet be pre-processed. The following are required for the dataset:
#
# - **Stanford Dogs Dataset**
# - URL: http://vision.stanford.edu/aditya86/ImageNetDogs/
#
# **Dataset Reference**
#
# **Primary:**
# Aditya Khosla, Nityananda Jayadevaprakash, Bangpeng Yao and Li Fei-Fei. **Novel dataset for Fine-Grained Image Categorization.** *First Workshop on Fine-Grained Visual Categorization (FGVC), IEEE Conference on Computer Vision and Pattern Recognition (CVPR)*, 2011.  [[pdf]](http://people.csail.mit.edu/khosla/papers/fgvc2011.pdf)  [[poster]](http://vision.stanford.edu/documents/KhoslaJayadevaprakashYaoFeiFei_FGVC2011.pdf)  [[BibTex]](http://vision.stanford.edu/bibTex/KhoslaJayadevaprakashYaoFeiFei_FGVC2011.bib)
#
# **Secondary:**
# J. Deng, W. Dong, R. Socher, L.-J. Li, K. Li and L. Fei-Fei, **ImageNet: A Large-Scale Hierarchical Image Database.** *IEEE Computer Vision and Pattern Recognition (CVPR)*, 2009.  [[pdf]](http://www.image-net.org/papers/imagenet_cvpr09.pdf)  [[BibTex]](http://www.image-net.org/papers/imagenet_cvpr09.bib)
#
# 1. The data includes at least 1000 images
#     1. Number of images: 20,580
#     2. There are 20,580 images, out of which 12,000 are used for training and 8580 for testing. Class labels and bounding box annotations are provided for all the 12,000 images.
# 2. The size of the images should be larger than 20x20 pixels
#     1. `Smallest image size: 97x100 pixels`
# 3. The dataset should have a well defined prediction task (i.e., a label for each image)
#     1. The well-defined prediction task for the **Stanford Dogs Dataset** dataset involves classifying the breed of a dog from its image.
# 4. The dataset cannot be MNIST or Fashion MNIST
#     1. Correct, the Stanford Dogs Dataset is not MNIST or Fashion MNIST.

# %% [markdown]
# A note on grading: This lab is mostly about visualizing and understanding your dataset. The largest share of the points is from how you interpret the visuals that you make. Making the visuals is not enough to satisfy each of the rubrics below—you should appropriately explain what the implications of the visualizations are. In other words, expect about 20% of the available points for visuals that have no substantive discussion.

# %% [markdown]
# **Grading Rubric**
#
# - Business Understanding (**2 points total**).
#     - [**2 points**] Give an overview of the dataset.
#         - The Stanford Dogs Dataset is a collection of images featuring 120 breeds of dogs from around the world. This dataset has been built using images and annotations from ImageNet for the task of classification. It contains over 20,000 images, each labeled with the breed of the dog present in the image.
#     - Describe the purpose of the data set you selected (i.e., why was this data collected in the first place?).
#         - The dataset was collected in the first place to test machine learning and computer vision algorithms to recognize and predict the breed of a dog from its image.
#     - What is the prediction task for your dataset and which third parties would be interested in the results?
#         - The well-defined prediction task for the Stanford Dogs Dataset is the classification of dog breeds. The third parties that would be interested are Academic Researchers, Tech Companies and of course, Veterinarians.
#     - Why is this data important?
#         - For Researchers, the results can advance research in depth perception and structured prediction in machine learning and computer vision. Since dog breeds are so similar, identifying them requires a model to learn nuanced features, which can significantly contribute to advancements in the field.
#     - Once you begin modeling, how well would your prediction algorithm need to perform to be considered useful to the identified third parties?
#         - The model should have a high accuracy rate in correctly identifying dog breeds. In practice, an accuracy rate of over 80% might be expected for professional applications. For user experience, the model should be efficient in terms of computation time and resource usage. And of course, the model must maintain high performance on images that were not part of the training dataset.
#     - Be specific and use your own words to describe the aspects of the data.

# %% [markdown]
# Exceptional Work (1 points total)

# %%
import cv2
import os
import tarfile
import io
from PIL import Image
import pandas as pd
import numpy as np
from numpy import dot as mmult
from numpy.linalg import inv
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA
import sklearn
from skimage.feature import daisy

# Print versions
print("cv2 version:", cv2.__version__)
print("pandas version:", pd.__version__)
print("numpy version:", np.__version__)
print("matplotlib version:", plt.matplotlib.__version__)
print("seaborn version:", sns.__version__)
print("missingno version:", msno.__version__)
print("sklearn version:", sklearn.__version__)
# Out:
# cv2 version: 4.6.0
# pandas version: 2.1.4
# numpy version: 1.26.3
# matplotlib version: 3.8.0
# seaborn version: 0.12.2
# missingno version: 0.4.2
# sklearn version: 1.2.2

# %%
label_tar_path = 'stanford_dogs/annotation.tar'

file_labels = {}

with tarfile.open(label_tar_path) as tar:
    for member in tar.getmembers():
        path_parts = member.name.split('/')
        if len(path_parts) >= 2:
            label = path_parts[1].split('-')[1]
            file_key = os.path.splitext(path_parts[-1])[0]
            file_labels[file_key] = label

# %% [markdown]
# To generate processed_images while integrating labels from annotation.tar, I need to adapt my code to include each image's label using the file_labels dictionary. I'll extract filenames from images.tar, match them with labels, and store them as tuples in processed_images. This tuple structure will pair each image array with its corresponding label for easy tracking. I'll then utilize this combined data for subsequent tasks like flattening images and adding labels to a NumPy array before PCA.

# %%
tar_path = 'stanford_dogs/images.tar'
smallest_width, smallest_height = float('inf'), float('inf')

with tarfile.open(tar_path) as tar:
    for member in tar.getmembers():
        if member.name.lower().endswith(('.jpg', '.jpeg', '.png')):
            file = tar.extractfile(member)
            if file:
                img = Image.open(io.BytesIO(file.read()))

                width, height = img.size
                smallest_width = min(smallest_width, width)
                smallest_height = min(smallest_height, height)

                img.close()

print(f'Smallest image size: {smallest_width}x{smallest_height} pixels')
# Out:
# Smallest image size: 97x100 pixels

# %% [markdown]
# Iterate through each image file within the specified tar archive. For each image, it reads its content, determines its width and height, and updates the smallest width and height encountered so far. After processing all images, it prints out the smallest image size found.

# %% [markdown]
# [.5 points] Resize and recolor images as necessary.

# %%
processed_images = []

with tarfile.open(tar_path) as tar:
    for member in tar.getmembers():
        if member.name.lower().endswith(('.jpg', '.jpeg', '.png')):
            file = tar.extractfile(member)
            if file:
                img = Image.open(io.BytesIO(file.read()))
                
                if img.mode != 'RGB':
                    img = img.convert('RGB')

                img = img.resize((smallest_width, smallest_height))
                
                img_array = np.array(img)
                
                filename_key = os.path.splitext(os.path.basename(member.name))[0]

                label = file_labels.get(filename_key, "Unknown")

                processed_images.append((img_array, label))
                
                img.close()

# %% [markdown]
# This code processes images stored within a tar archive. It iterates through each member of the archive, checks if it's an image file (ending with '.jpg', '.jpeg', or '.png'), extracts it, converts it to RGB mode if necessary, resizes it to a predefined width and height, converts it into a NumPy array, associates it with a label based on its filename, and finally stores the image array-label pair in a list for further use.

# %% [markdown]
# Data Preparation (1 points total)
# [.1 points] Visualize several images.

# %%
# Visualize first few images along with their labels
for img, label in processed_images[:5]:
    plt.imshow(img)
    plt.title(f"Label: {label}")
    plt.show()

# %% [markdown]
# Data Preparation (1 points total)
#
# [.5 points] Read in your images as numpy arrays. Resize and recolor images as necessary.
#
# [.4 points] Linearize the images to create a table of 1-D image features (each row should be one image).
#
#
# Given that each element in processed_images is a tuple containing both the image array and its corresponding label, we just need to flatten only the image portion of each tuple.

# %%
linearized_images_with_labels = []
flattened_images = []
labels = []
for img, label in processed_images:
    flattened_img = np.array(img).flatten()
    linearized_images_with_labels.append((flattened_img, label))
    flattened_images.append(flattened_img)
    labels.append(label)

# %%
X_pca = np.array(flattened_images)
Y_pca = np.array(labels)
X_randomized_pca = np.array(flattened_images)
Y_randomized_pca = np.array(labels)

# %% [markdown]
# When dealing with a particularly large dataset and facing memory limitations on my machine, I encountered issues trying to fit a PCA (Principal Component Analysis) model directly on the entire dataset.
# To address this challenge, I wanted to use IncrementalPCA, a model designed specifically for working with large datasets in a memory-efficient manner.

# %%
n_components = 100 
batch_size = 1000

ipca = IncrementalPCA(n_components=n_components, batch_size=batch_size)

def generate_batches(data, batch_size):
    for i in range(0, len(data), batch_size):
        yield data[i:i+batch_size]

# Iterate over batches and fit IncrementalPCA
for X_batch in generate_batches(X_pca, batch_size):
    ipca.partial_fit(X_batch)

# %%
# Transform the entire dataset using the fitted IncrementalPCA
X_pca_transformed = ipca.transform(X_pca)

# %%
cumulative_variance = np.cumsum(ipca.explained_variance_ratio_)

# %% [markdown]
# Visualize Explained Variance:
# Plot the cumulative explained variance against the number of components. This visualization helps determine how many components are needed to represent the data adequately.

# %%
# Plot the cumulative explained variance
plt.figure(figsize=(10, 6))
plt.plot(cumulative_variance, marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by PCA Components')
plt.grid(True)
plt.show()

# %% [markdown]
# When Determining the number of PCAs, it is a good rule of thumb to look for the 'elbow' in the Number of Components vs Cumulative Explained Variance plot. After the 'elbow', the cumulative variance starts to have diminishing returns. This point is typically considered an adequate balance between information retention and dimensionality reduction.
#
# The provided graph displays the cumulative explained variance by the number of principal components from a PCA analysis. From this graph, up to the 75th component, there is a rapid increase in explained variance, indicating that these components capture most of the significant information from the dataset.
# After approximately 75 components, the curve's slope decreases, suggesting that each additional component contributes less to the model's explanatory power.
#
# 75 number of components balances capturing the variance (information) but also reduces the dimensions effectively.

# %% [markdown]
# [.**5 points**] Perform linear dimensionality reduction of your image data using **randomized principle components analysis**.
# - Visualize the explained variance of each component.
# - Analyze how many dimensions are required to adequately represent your image data.
# - Explain your analysis and conclusion.

# %%
n_components = 75 # from standard PCA
randomized_pca = PCA(n_components=n_components, svd_solver='randomized', random_state=33)

# %%
# Fit the PCA model to the image data
randomized_pca.fit(X_randomized_pca)
# Out:
# PCA(n_components=75, random_state=33, svd_solver='randomized')

# %%
# Transform the entire dataset using the fitted PCA
X_randomized_pca_transformed = randomized_pca.transform(X_randomized_pca)

# %%
# Calculate cumulative explained variance
cumulative_variance = np.cumsum(randomized_pca.explained_variance_ratio_)

# %% [markdown]
# - Visualize the explained variance of each component.

# %%
# Plot the cumulative explained variance
plt.figure(figsize=(10, 6))
plt.plot(cumulative_variance, marker='o')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by Randomized PCA Components')
plt.grid(True)
plt.show()

# %% [markdown]
# - Analyze how many dimensions are required to adequately represent your image data.
# - Explain your analysis and conclusion.

# %% [markdown]
# This graph illustrates the cumulative explained variance based on the number of principal components derived from a PCA analysis. It demonstrates a steep rise in explained variance up to the 30th component, suggesting that these components effectively capture the majority of significant information from the dataset. Beyond approximately 30 components, the curve's incline becomes less pronounced, indicating diminishing returns in terms of each additional component's contribution to the model's explanatory power.
#
# Having 30 components strikes a balance between capturing variance (information) and effectively reducing dimensions.

# %% [markdown]
# [**2 points**] Compare the representation using PCA and Randomized PCA.
# - The method you choose to compare dimensionality methods should quantitatively explain which method is better at representing the images with fewer components.

# %% [markdown]
# To compare the representation using PCA and Randomized PCA, we can analyze their cumulative explained variance curves and assess their performance in representing images with fewer components quantitatively.
#
# - For PCA: Up to the 75th component, there is a rapid increase in explained variance, indicating effective capture of significant information. Beyond 75 components, the rate of increase slows down, suggesting diminishing returns in explanatory power.
# - For Randomized PCA: Up to the 30th component, there is a rapid increase in explained variance, indicating effective capture of significant information. Beyond 30 components, the rate of increase slows down, suggesting diminishing returns in explanatory power.
#
# Quantitatively, PCA captures more variance with 75 components compared to Randomized PCA's 30 components, suggesting a more comprehensive representation. However, Randomized PCA may offer faster computation, making it preferable for large datasets with limited computational resources.

# %% [markdown]
# - Do you prefer one method over another? Why?
#
# The decision to use Randomized PCA was driven by limitations in memory and computational resources. This variant of Principal Component Analysis offers faster computation, making it suitable for large datasets where traditional PCA might be impractical. Although Randomized PCA sacrifices some variance capture compared to standard PCA, this trade-off is acceptable given the priority of conserving computational resources. Thus, Randomized PCA was chosen to strike a balance between computational efficiency and accuracy in dimensionality reduction.

# %% [markdown]
# [1 points] Perform feature extraction upon the images using any feature extraction technique (e.g., gabor filters, ordered gradients, DAISY, etc.).

# %%
expected_num_images, expected_num_features = X_pca.shape

print("Expected number of images:", expected_num_images)
print("Expected number of features per image:", expected_num_features)
# Out:
# Expected number of images: 20580
# Expected number of features per image: 29100

# %% [markdown]
# The daisy function from the scikit-image library expects a 2-dimensional array as input because it operates on grayscale images. It computes DAISY descriptors, which are local image descriptors designed for grayscale images. These descriptors capture local spatial structures in the image, which are typically encoded in intensity variations.
#
# While it's possible to apply DAISY feature extraction to color images, it requires additional preprocessing steps. One common approach is to convert the color image to a grayscale image and then compute DAISY descriptors on the grayscale version. However, this approach discards color information, which might be important for certain tasks.
#
# If you want to keep color information while using DAISY features, you can extract separate DAISY descriptors for each color channel (e.g., red, green, and blue) and concatenate them together. This way, you can preserve color information while still leveraging DAISY descriptors for feature extraction.

# %%
subset_size = 10000 

# DAISY parameters
radius = 15
num_rings = 3
num_hist_bins = 8
num_orientations = 8

subset_features = []
y_subset = []

for img, label in processed_images[:subset_size]:
    # Compute DAISY features for each color channel
    channel_features = []
    for channel in range(img.shape[2]):
        daisy_features = daisy(img[:, :, channel], step=8, radius=radius, rings=num_rings, histograms=num_hist_bins, orientations=num_orientations)
        flattened_features = daisy_features.reshape(-1)
        channel_features.append(flattened_features)
    
    concatenated_features = np.concatenate(channel_features)
    
    subset_features.append(concatenated_features)
    
    y_subset.append(label)

# Convert the feature list and label list to numpy arrays
X_subset = np.array(subset_features)
y_subset = np.array(y_subset)

# %%
# Check the mean and standard deviation of each feature
feature_means = np.mean(X_subset, axis=0)
feature_stds = np.std(X_subset, axis=0)

print("Feature means:", feature_means)
print("Feature standard deviations:", feature_stds)
# Out:
# Feature means: [0.00455219 0.00485452 0.00441564 ... 0.00498929 0.00482693 0.00423929]
# Feature standard deviations: [0.0034541  0.00313815 0.00325493 ... 0.00215847 0.00234301 0.00198554]

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

X_train, X_test, y_train, y_test = train_test_split(X_subset, y_subset, test_size=0.2, random_state=33)

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# /Users/charlesbryan/anaconda3/envs/002C_1242/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/charlesbryan/anaconda3/envs/002C_1242/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/charlesbryan/anaconda3/envs/002C_1242/lib/python3.11/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                 precision    recall  f1-score   support
#
#                   Afghan_hound       0.17      0.16      0.17        57
#                       Airedale       0.02      0.05      0.03        43
# American_Staffordshire_terrier       0.00      0.00      0.00        27
#             Australian_terrier       0.02      0.03      0.02        39
#             Bedlington_terrier       0.21      0.11      0.14        38
#               Blenheim_spaniel       0.00      0.00      0.00        42
#                 Border_terrier       0.01      0.03      0.01        30
#                    Boston_bull       0.07      0.05      0.05        44
#                      Chihuahua       0.10      0.07      0.08        28
#                 Dandie_Dinmont       0.04      0.08      0.05        39
#                   Ibizan_hound       0.05      0.12      0.07        41
#                  Irish_terrier       0.02      0.03      0.02        32
#                Irish_wolfhound       0.07      0.07      0.07        40
#              Italian_greyhound       0.05      0.08      0.06        39
#               Japanese_spaniel       0.75      0.07      0.13        41
#             Kerry_blue_terrier       0.09      0.34      0.14        38
#             Labrador_retriever       0.00      0.00      0.00        34
#               Lakeland_terrier       0.26      0.16      0.20        38
#                          Lhasa       0.07      0.07      0.07        28
#                    Maltese_dog       0.13      0.04      0.06        52
#                Norfolk_terrier       0.09      0.07      0.08        40
#             Norwegian_elkhound       0.03      0.32      0.06        41
#                Norwich_terrier       0.05      0.05      0.05        39
#                       Pekinese       0.08      0.03      0.04        34
#            Rhodesian_ridgeback       0.00      0.00      0.00        25
#                         Saluki       0.08      0.07      0.08        28
#                 Scotch_terrier       0.27      0.11      0.15        37
#             Scottish_deerhound       0.10      0.07      0.08        43
#               Sealyham_terrier       0.57      0.23      0.33        35
#                           Shih       0.00      0.00      0.00        35
#      Staffordshire_bullterrier       0.04      0.03      0.04        29
#                Tibetan_terrier       0.18      0.05      0.07        43
#                   Walker_hound       0.00      0.00      0.00        29
#                     Weimaraner       0.00      0.00      0.00        26
#    West_Highland_white_terrier       0.00      0.00      0.00        33
#              Yorkshire_terrier       0.00      0.00      0.00        26
#                         basset       0.00      0.00      0.00        36
#                         beagle       0.00      0.00      0.00        39
#                          black       0.29      0.05      0.08        42
#                     bloodhound       0.33      0.02      0.04        44
#                       bluetick       0.09      0.02      0.04        42
#                         borzoi       0.00      0.00      0.00        25
#                          cairn       0.12      0.02      0.04        47
#                          curly       0.15      0.06      0.09        33
#                           flat       0.00      0.00      0.00        31
#                giant_schnauzer       0.00      0.00      0.00        32
#               golden_retriever       0.00      0.00      0.00        31
#            miniature_schnauzer       0.00      0.00      0.00        36
#                       papillon       0.00      0.00      0.00        36
#                        redbone       0.00      0.00      0.00        38
#                  silky_terrier       0.05      0.08      0.07        24
#                           soft       0.08      0.05      0.06        22
#             standard_schnauzer       0.00      0.00      0.00        29
#                    toy_terrier       0.00      0.00      0.00        32
#                        whippet       0.00      0.00      0.00        34
#                           wire       0.67      0.06      0.11        34
#
#                       accuracy                           0.06      2000
#                      macro avg       0.10      0.05      0.05      2000
#                   weighted avg       0.10      0.06      0.06      2000

# %% [markdown]
# [**2 points**] Does this feature extraction method show promise for your prediction task?
# - Why? Use visualizations to analyze this questions.
# - For example, visualize the differences **between statistics of extracted features** in each target class.
# - Another option, use a heat map of the pairwise differences (ordered by class) among all extracted features.
# - Another option, build a nearest neighbor classifier to see actual classification performance.

# %% [markdown]
# Based on the classification report I analyzed, it appears that the DAISY feature extraction method isn't very effective for my prediction task. Here's a summary of my observations:
#
# Overall Accuracy: The accuracy of my classifier is just 6%, which is disappointingly low. This indicates that the classifier is generally not identifying the classes correctly.
#
# Precision and Recall Concerns: Across most classes, both precision and recall are low. This means that not only are many of my positive predictions incorrect, but the classifier is also missing a lot of true positive instances.
#
# It seems DAISY features, which focus on texture, may not be the most effective for distinguishing between dog breeds.

# %% [markdown]
# In conclusion, my current approach using DAISY feature extraction doesn't seem suitable for classifying dog breeds effectively. I might need to explore other feature extraction methods, possibly those based on deep learning, which could better capture the distinct characteristics of different breeds.

# %% [markdown]
# Exceptional Work (**1 points total**)
# - You have free reign to provide any additional analyses.
# - One idea (**required for 7000 level students**): Perform feature extraction upon the images using DAISY. Rather than using matching on the images with the total DAISY vector, you will **instead use key point matching**. You will need to investigate appropriate methods for key point matching using DAISY. NOTE: this often requires some type of brute force matching per pair of images, which can be computationally expensive. Does it perform better than not using key point matching?

# %%
# helped by ChatGPT to write the extract_daisy_keypoints function
def extract_daisy_keypoints(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    keypoints = cv2.goodFeaturesToTrack(gray_image, maxCorners=1000, qualityLevel=0.01, minDistance=10)

    # Check if keypoints are found
    if keypoints is not None:
        keypoints = [cv2.KeyPoint(x=kp[0][0], y=kp[0][1], size=10) for kp in keypoints]
        # You need to use a DAISY descriptor extractor
        daisy = cv2.xfeatures2d.DAISY_create()
        keypoints, descriptors = daisy.compute(gray_image, keypoints)
    else:
        keypoints, descriptors = [], []

    return keypoints, descriptors


# Extract DAISY keypoints and descriptors for each image
subset_keypoints = []
subset_descriptors = []
for img, label in processed_images[:subset_size]:
    keypoints, descriptors = extract_daisy_keypoints(img)
    subset_keypoints.append(keypoints)
    subset_descriptors.append(descriptors)

# Perform keypoint matching
matcher = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)
matches = []
for i in range(len(subset_descriptors) - 1):
    matches.append(matcher.match(subset_descriptors[i], subset_descriptors[i+1]))

num_matches = [len(match) for match in matches]
for i, num_match in enumerate(num_matches):
    print(f"Number of matches for image pair {i}: {num_match}")
# Out:
# Number of matches for image pair 0: 8
# Number of matches for image pair 1: 8
# Number of matches for image pair 2: 12
# Number of matches for image pair 3: 13
# Number of matches for image pair 4: 10
# Number of matches for image pair 5: 11
# Number of matches for image pair 6: 5
# Number of matches for image pair 7: 10
# Number of matches for image pair 8: 14
# Number of matches for image pair 9: 5
# Number of matches for image pair 10: 12
# Number of matches for image pair 11: 8
# Number of matches for image pair 12: 7
# Number of matches for image pair 13: 9
# Number of matches for image pair 14: 10
# Number of matches for image pair 15: 13
# Number of matches for image pair 16: 8
# Number of matches for image pair 17: 4
# Number of matches for image pair 18: 5
# Number of matches for image pair 19: 6
# Number of matches for image pair 20: 8
# Number of matches for image pair 21: 11
# Number of matches for image pair 22: 13
# Number of matches for image pair 23: 7
# Number of matches for image pair 24: 2
# Number of matches for image pair 25: 2
# Number of matches for image pair 26: 5
# Number of matches for image pair 27: 11
# Number of matches for image pair 28: 9
# Number of matches for image pair 29: 13
# Number of matches for image pair 30: 16
# Number of matches for image pair 31: 8
# Number of matches for image pair 32: 10
# Number of matches for image pair 33: 11
# Number of matches for image pair 34: 11
# Number of matches for image pair 35: 10
# Number of matches for image pair 36: 10
# Number of matches for image pair 37: 4
# Number of matches for image pair 38: 7
# Number of matches for image pair 39: 11
# Number of matches for image pair 40: 8
# Number of matches for image pair 41: 2
# Number of matches for image pair 42: 16
# Number of matches for image pair 43: 14
# Number of matches for image pair 44: 13
# Number of matches for image pair 45: 13
# Number of matches for image pair 46: 12
# Number of matches for image pair 47: 9
# Number of matches for image pair 48: 10
# Number of matches for image pair 49: 14
# Number of matches for image pair 50: 12
# Number of matches for image pair 51: 10
# Number of matches for image pair 52: 5
# Number of matches for image pair 53: 6
# Number of matches for image pair 54: 10
# Number of matches for image pair 55: 12
# Number of matches for image pair 56: 8
# Number of matches for image pair 57: 11
# Number of matches for image pair 58: 11
# Number of matches for image pair 59: 9
# Number of matches for image pair 60: 12
# Number of matches for image pair 61: 10
# Number of matches for image pair 62: 7
# Number of matches for image pair 63: 14
# Number of matches for image pair 64: 11
# Number of matches for image pair 65: 9
# Number of matches for image pair 66: 8
# Number of matches for image pair 67: 11
# Number of matches for image pair 68: 7
# Number of matches for image pair 69: 5
# Number of matches for image pair 70: 6
# Number of matches for image pair 71: 3
# Number of matches for image pair 72: 9
# Number of matches for image pair 73: 8
# Number of matches for image pair 74: 11
# Number of matches for image pair 75: 10
# Number of matches for image pair 76: 5
# Number of matches for image pair 9648: 20
# Number of matches for image pair 9649: 14
# Number of matches for image pair 9650: 11
# Number of matches for image pair 9651: 10
# Number of matches for image pair 9652: 17
# Number of matches for image pair 9653: 11
# Number of matches for image pair 9654: 15
# Number of matches for image pair 9655: 16
# Number of matches for image pair 9656: 16
# Number of matches for image pair 9657: 14
# Number of matches for image pair 9658: 14
# Number of matches for image pair 9659: 18
# Number of matches for image pair 9660: 23
# Number of matches for image pair 9661: 17
# Number of matches for image pair 9662: 14
# Number of matches for image pair 9663: 12
# Number of matches for image pair 9664: 7
# Number of matches for image pair 9665: 12
# Number of matches for image pair 9666: 6
# Number of matches for image pair 9667: 3
# Number of matches for image pair 9668: 2
# Number of matches for image pair 9669: 9
# Number of matches for image pair 9670: 19
# Number of matches for image pair 9671: 11
# Number of matches for image pair 9672: 9
# Number of matches for image pair 9673: 12
# Number of matches for image pair 9674: 8
# Number of matches for image pair 9675: 1
# Number of matches for image pair 9676: 10
# Number of matches for image pair 9677: 12
# Number of matches for image pair 9678: 7
# Number of matches for image pair 9679: 15
# Number of matches for image pair 9680: 12
# Number of matches for image pair 9681: 17
# Number of matches for image pair 9682: 9
# Number of matches for image pair 9683: 18
# Number of matches for image pair 9684: 7
# Number of matches for image pair 9685: 5
# Number of matches for image pair 9686: 19
# Number of matches for image pair 9687: 10
# Number of matches for image pair 9688: 18
# Number of matches for image pair 9689: 21
# Number of matches for image pair 9690: 4
# Number of matches for image pair 9691: 4
# Number of matches for image pair 9692: 14
# Number of matches for image pair 9693: 13
# Number of matches for image pair 9694: 9
# Number of matches for image pair 9695: 10
# Number of matches for image pair 9696: 8
# Number of matches for image pair 9697: 14
# Number of matches for image pair 9698: 10
# Number of matches for image pair 9699: 13
# Number of matches for image pair 9700: 16
# Number of matches for image pair 9701: 12
# Number of matches for image pair 9702: 6
# Number of matches for image pair 9703: 7
# Number of matches for image pair 9704: 8
# Number of matches for image pair 9705: 17
# Number of matches for image pair 9706: 3
# Number of matches for image pair 9707: 7
# Number of matches for image pair 9708: 11
# Number of matches for image pair 9709: 9
# Number of matches for image pair 9710: 3
# Number of matches for image pair 9711: 7
# Number of matches for image pair 9712: 9
# Number of matches for image pair 9713: 9
# Number of matches for image pair 9714: 9
# Number of matches for image pair 9715: 8
# Number of matches for image pair 9716: 11
# Number of matches for image pair 9717: 5
# Number of matches for image pair 9718: 5
# Number of matches for image pair 9719: 11
# Number of matches for image pair 9720: 10
# Number of matches for image pair 9721: 9
# Number of matches for image pair 9722: 7
# Number of matches for image pair 9723: 9
# Number of matches for image pair 9724: 5
# Number of matches for image pair 9725: 5
# Number of matches for image pair 9726: 2
# Number of matches for image pair 9727: 8
# Number of matches for image pair 9728: 16
# Number of matches for image pair 9729: 17
# Number of matches for image pair 9730: 14
# Number of matches for image pair 9731: 14
# Number of matches for image pair 9732: 10
# Number of matches for image pair 9733: 6
# Number of matches for image pair 9734: 10
# Number of matches for image pair 9735: 11
# Number of matches for image pair 9736: 14
# Number of matches for image pair 9737: 5
# Number of matches for image pair 9738: 14
# Number of matches for image pair 9739: 9
# Number of matches for image pair 9740: 4
# Number of matches for image pair 9741: 11
# Number of matches for image pair 9742: 11
# Number of matches for image pair 9743: 13
# Number of matches for image pair 9744: 11
# Number of matches for image pair 9745: 5
# Number of matches for image pair 9746: 6
# Number of matches for image pair 9747: 12
# Number of matches for image pair 9748: 8
# Number of matches for image pair 9749: 14
# Number of matches for image pair 9750: 18
# Number of matches for image pair 9751: 11
# Number of matches for image pair 9752: 8
# Number of matches for image pair 9753: 9
# Number of matches for image pair 9754: 11
# Number of matches for image pair 9755: 11
# Number of matches for image pair 9756: 12
# Number of matches for image pair 9757: 16
# Number of matches for image pair 9758: 8
# Number of matches for image pair 9759: 9
# Number of matches for image pair 9760: 11
# Number of matches for image pair 9761: 9
# Number of matches for image pair 9762: 8
# Number of matches for image pair 9763: 9
# Number of matches for image pair 9764: 13
# Number of matches for image pair 9765: 11
# Number of matches for image pair 9766: 9
# Number of matches for image pair 9767: 8
# Number of matches for image pair 9768: 7
# Number of matches for image pair 9769: 9
# Number of matches for image pair 9770: 13
# Number of matches for image pair 9771: 8
# Number of matches for image pair 9772: 10
# Number of matches for image pair 9773: 10
# Number of matches for image pair 9774: 11
# Number of matches for image pair 9775: 13
# Number of matches for image pair 9776: 11
# Number of matches for image pair 9777: 9
# Number of matches for image pair 9778: 10
# Number of matches for image pair 9779: 9
# Number of matches for image pair 9780: 6
# Number of matches for image pair 9781: 5
# Number of matches for image pair 9782: 15
# Number of matches for image pair 9783: 8
# Number of matches for image pair 9784: 7
# Number of matches for image pair 9785: 10
# Number of matches for image pair 9786: 15
# Number of matches for image pair 9787: 11
# Number of matches for image pair 9788: 18
# Number of matches for image pair 9789: 13
# Number of matches for image pair 9790: 11
# Number of matches for image pair 9791: 11
# Number of matches for image pair 9792: 12
# Number of matches for image pair 9793: 11
# Number of matches for image pair 9794: 15
# Number of matches for image pair 9795: 12
# Number of matches for image pair 9796: 7
# Number of matches for image pair 9797: 9
# Number of matches for image pair 9798: 11
# Number of matches for image pair 9799: 10
# Number of matches for image pair 9800: 7
# Number of matches for image pair 9801: 15
# Number of matches for image pair 9802: 5
# Number of matches for image pair 9803: 5
# Number of matches for image pair 9804: 5
# Number of matches for image pair 9805: 14
# Number of matches for image pair 9806: 10
# Number of matches for image pair 9807: 7
# Number of matches for image pair 9808: 14
# Number of matches for image pair 9809: 10
# Number of matches for image pair 9810: 8
# Number of matches for image pair 9811: 12
# Number of matches for image pair 9812: 22
# Number of matches for image pair 9813: 12
# Number of matches for image pair 9814: 12
# Number of matches for image pair 9815: 11
# Number of matches for image pair 9816: 10
# Number of matches for image pair 9817: 12
# Number of matches for image pair 9818: 8
# Number of matches for image pair 9819: 9
# Number of matches for image pair 9820: 14
# Number of matches for image pair 9821: 6
# Number of matches for image pair 9822: 5
# Number of matches for image pair 9823: 13
# Number of matches for image pair 9824: 14
# Number of matches for image pair 9825: 10
# Number of matches for image pair 9826: 16
# Number of matches for image pair 9827: 10
# Number of matches for image pair 9828: 5
# Number of matches for image pair 9829: 10
# Number of matches for image pair 9830: 12
# Number of matches for image pair 9831: 11
# Number of matches for image pair 9832: 11
# Number of matches for image pair 9833: 12
# Number of matches for image pair 9834: 13
# Number of matches for image pair 9835: 6
# Number of matches for image pair 9836: 5
# Number of matches for image pair 9837: 5
# Number of matches for image pair 9838: 9
# Number of matches for image pair 9839: 15
# Number of matches for image pair 9840: 11
# Number of matches for image pair 9841: 13
# Number of matches for image pair 9842: 13
# Number of matches for image pair 9843: 10
# Number of matches for image pair 9844: 8
# Number of matches for image pair 9845: 6
# Number of matches for image pair 9846: 10
# Number of matches for image pair 9847: 8
# Number of matches for image pair 9848: 6
# Number of matches for image pair 9849: 11
# Number of matches for image pair 9850: 12
# Number of matches for image pair 9851: 14
# Number of matches for image pair 9852: 9
# Number of matches for image pair 9853: 11
# Number of matches for image pair 9854: 16
# Number of matches for image pair 9855: 12
# Number of matches for image pair 9856: 10
# Number of matches for image pair 9857: 11
# Number of matches for image pair 9858: 16
# Number of matches for image pair 9859: 8
# Number of matches for image pair 9860: 10
# Number of matches for image pair 9861: 10
# Number of matches for image pair 9862: 9
# Number of matches for image pair 9863: 10
# Number of matches for image pair 9864: 8
# Number of matches for image pair 9865: 7
# Number of matches for image pair 9866: 7
# Number of matches for image pair 9867: 10
# Number of matches for image pair 9868: 11
# Number of matches for image pair 9869: 10
# Number of matches for image pair 9870: 8
# Number of matches for image pair 9871: 4
# Number of matches for image pair 9872: 7
# Number of matches for image pair 9873: 5
# Number of matches for image pair 9874: 5
# Number of matches for image pair 9875: 9
# Number of matches for image pair 9876: 6
# Number of matches for image pair 9877: 7
# Number of matches for image pair 9878: 4
# Number of matches for image pair 9879: 9
# Number of matches for image pair 9880: 10
# Number of matches for image pair 9881: 5
# Number of matches for image pair 9882: 4
# Number of matches for image pair 9883: 11
# Number of matches for image pair 9884: 10
# Number of matches for image pair 9885: 13
# Number of matches for image pair 9886: 9
# Number of matches for image pair 9887: 11
# Number of matches for image pair 9888: 10
# Number of matches for image pair 9889: 8
# Number of matches for image pair 9890: 6
# Number of matches for image pair 9891: 9
# Number of matches for image pair 9892: 13
# Number of matches for image pair 9893: 4
# Number of matches for image pair 9894: 7
# Number of matches for image pair 9895: 8
# Number of matches for image pair 9896: 12
# Number of matches for image pair 9897: 14
# Number of matches for image pair 9898: 10
# Number of matches for image pair 9899: 13
# Number of matches for image pair 9900: 11
# Number of matches for image pair 9901: 11
# Number of matches for image pair 9902: 7
# Number of matches for image pair 9903: 9
# Number of matches for image pair 9904: 9
# Number of matches for image pair 9905: 9
# Number of matches for image pair 9906: 10
# Number of matches for image pair 9907: 10
# Number of matches for image pair 9908: 6
# Number of matches for image pair 9909: 2
# Number of matches for image pair 9910: 9
# Number of matches for image pair 9911: 8
# Number of matches for image pair 9912: 8
# Number of matches for image pair 9913: 15
# Number of matches for image pair 9914: 10
# Number of matches for image pair 9915: 6
# Number of matches for image pair 9916: 6
# Number of matches for image pair 9917: 5
# Number of matches for image pair 9918: 12
# Number of matches for image pair 9919: 8
# Number of matches for image pair 9920: 9
# Number of matches for image pair 9921: 4
# Number of matches for image pair 9922: 17
# Number of matches for image pair 9923: 9
# Number of matches for image pair 9924: 11
# Number of matches for image pair 9925: 9
# Number of matches for image pair 9926: 6
# Number of matches for image pair 9927: 6
# Number of matches for image pair 9928: 8
# Number of matches for image pair 9929: 8
# Number of matches for image pair 9930: 4
# Number of matches for image pair 9931: 4
# Number of matches for image pair 9932: 6
# Number of matches for image pair 9933: 9
# Number of matches for image pair 9934: 9
# Number of matches for image pair 9935: 12
# Number of matches for image pair 9936: 5
# Number of matches for image pair 9937: 2
# Number of matches for image pair 9938: 6
# Number of matches for image pair 9939: 7
# Number of matches for image pair 9940: 7
# Number of matches for image pair 9941: 8
# Number of matches for image pair 9942: 6
# Number of matches for image pair 9943: 11
# Number of matches for image pair 9944: 17
# Number of matches for image pair 9945: 11
# Number of matches for image pair 9946: 9
# Number of matches for image pair 9947: 14
# Number of matches for image pair 9948: 14
# Number of matches for image pair 9949: 11
# Number of matches for image pair 9950: 8
# Number of matches for image pair 9951: 12
# Number of matches for image pair 9952: 11
# Number of matches for image pair 9953: 4
# Number of matches for image pair 9954: 4
# Number of matches for image pair 9955: 6
# Number of matches for image pair 9956: 5
# Number of matches for image pair 9957: 8
# Number of matches for image pair 9958: 5
# Number of matches for image pair 9959: 6
# Number of matches for image pair 9960: 12
# Number of matches for image pair 9961: 11
# Number of matches for image pair 9962: 11
# Number of matches for image pair 9963: 10
# Number of matches for image pair 9964: 10
# Number of matches for image pair 9965: 14
# Number of matches for image pair 9966: 13
# Number of matches for image pair 9967: 9
# Number of matches for image pair 9968: 8
# Number of matches for image pair 9969: 11
# Number of matches for image pair 9970: 7
# Number of matches for image pair 9971: 8
# Number of matches for image pair 9972: 11
# Number of matches for image pair 9973: 5
# Number of matches for image pair 9974: 5
# Number of matches for image pair 9975: 8
# Number of matches for image pair 9976: 10
# Number of matches for image pair 9977: 10
# Number of matches for image pair 9978: 11
# Number of matches for image pair 9979: 12
# Number of matches for image pair 9980: 13
# Number of matches for image pair 9981: 11
# Number of matches for image pair 9982: 13
# Number of matches for image pair 9983: 8
# Number of matches for image pair 9984: 6
# Number of matches for image pair 9985: 10
# Number of matches for image pair 9986: 15
# Number of matches for image pair 9987: 4
# Number of matches for image pair 9988: 8
# Number of matches for image pair 9989: 14
# Number of matches for image pair 9990: 10
# Number of matches for image pair 9991: 13
# Number of matches for image pair 9992: 5
# Number of matches for image pair 9993: 8
# Number of matches for image pair 9994: 7
# Number of matches for image pair 9995: 8
# Number of matches for image pair 9996: 8
# Number of matches for image pair 9997: 10
# Number of matches for image pair 9998: 10

# %% [markdown]
# Keypoint matching is essential in various computer vision tasks such as object recognition, image registration, and structure from motion.
# DAISY features offer robustness to changes in viewpoint and illumination, making them suitable for tasks where traditional methods like SIFT or SURF may not perform well.

# %% [markdown]
# Performs keypoint matching between a set of images using DAISY features.
# It involves extracting DAISY keypoints and descriptors from a subset of processed images, and then matching these keypoints between consecutive images to find correspondences.
